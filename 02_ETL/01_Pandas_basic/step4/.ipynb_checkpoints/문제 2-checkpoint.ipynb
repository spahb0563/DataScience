# %%
import pandas as pd

# %% [markdown]
# ## 다음 데이터에서 일자별 음악들의 총 재생횟수의 합을 구하여라

# %%
data = pd.read_csv('../data/musicData.csv', index_col='Date', parse_dates=True,encoding='utf-8')

# %%
data
# Out:
#                                   Album Title      Artist Name     Genre  \
# Date
# 2018-09-01                      거기가 어딘데?? OST  Various Artists     O.S.T
# 2018-09-01                                  얍     갈릭스(Garlixx)  인디뮤직,  락
# 2018-09-01                               너와 나              파란        발라드
# 2018-09-01                 PRODUCE 48 - FINAL       PRODUCE 48        댄스
# 2018-09-01  Weather : 오늘 당신의 날씨는 어떤가요? Part 4              이진아        재즈
# ...                                       ...              ...       ...
# 2018-10-11                       It's a TRAP!       넘넘(numnum)  인디뮤직,  락
# 2018-10-11                Kryptonite (크립토나이트)      Seiren(세이렌)      랩/힙합
# 2018-10-11      Sandwich, Milk (Feat. divin')           C.Koon      랩/힙합
# 2018-10-11             손 the guest OST Part 2              손승연     드라마음악
# 2018-10-11                                꽃처럼      페르시(persie)       발라드
#
#                          Distribution  Rating  Music Count
# Date
# ...

# %%
data.index
# Out:
# DatetimeIndex(['2018-09-01', '2018-09-01', '2018-09-01', '2018-09-01',
#                '2018-09-01', '2018-09-01', '2018-09-02', '2018-09-02',
#                '2018-09-02', '2018-09-02',
#                ...
#                '2018-10-11', '2018-10-11', '2018-10-11', '2018-10-11',
#                '2018-10-11', '2018-10-11', '2018-10-11', '2018-10-11',
#                '2018-10-11', '2018-10-11'],
#               dtype='datetime64[ns]', name='Date', length=996, freq=None)

# %%
daily = data.resample('D')['Music Count'].sum()

# %%
daily
# Out:
# Date
# 2018-09-01     27
# 2018-09-02     53
# 2018-09-03     91
# 2018-09-04    170
# 2018-09-05     82
# 2018-09-06     76
# 2018-09-07    136
# 2018-09-08     27
# 2018-09-09     48
# 2018-09-10    134
# 2018-09-11     64
# 2018-09-12     70
# 2018-09-13    131
# 2018-09-14     80
# 2018-09-15     43
# 2018-09-16     46
# 2018-09-17     99
# 2018-09-18    110
# 2018-09-19    105
# 2018-09-20     92
# 2018-09-21     82
# 2018-09-22     79
# 2018-09-23     40
# 2018-09-24     12
# 2018-09-25     31
# 2018-09-26     22
# 2018-09-27     72
# 2018-09-28    104
# 2018-09-29     46
# 2018-09-30     17
# 2018-10-01    153
# 2018-10-02    132
# 2018-10-03     42
# 2018-10-04    168
# 2018-10-05     66
# 2018-10-06     28
# 2018-10-07     10
# 2018-10-08     77
# 2018-10-09     40
# 2018-10-10    106
# 2018-10-11     54
# Freq: D, Name: Music Count, dtype: int64
