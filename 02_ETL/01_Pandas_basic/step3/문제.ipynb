# %%
import pandas as pd

# %% [markdown]
# ## kospi 엑셀 자료가 주어진다. 이 자료에서 홈페이지가 비어있는 자료의 갯수를 구하여라

# %%
kospi = pd.read_csv('../data/kospi.csv',encoding='utf-8')

# %%
kospi
# Out:
#           회사명    종목코드                        업종  \
# 0        세아제강  306200                 1차 철강 제조업
# 1        하나제약  293480                   의약품 제조업
# 2     우진아이엔에스   10400               건물설비 설치 공사업
# 3      신한알파리츠  293940              부동산 임대 및 공급업
# 4       한일시멘트  300720  시멘트, 석회, 플라스터 및 그 제품 제조업
# ..        ...     ...                       ...
# 784    CJ대한통운     120                 도로 화물 운송업
# 785     메리츠화재      60                       보험업
# 786        경방      50              방적 및 가공사 제조업
# 787     유수홀딩스     700       회사 본부 및 경영 컨설팅 서비스업
# 788  한진중공업홀딩스    3480                    기타 금융업
#
#                                                   주요제품         상장일  결산월  \
# 0                                                   강관  2018-10-05  12월
# 1                                                완제의약품  2018-10-02  12월
# 2                                       반도체/디스플레이 코팅덕트  2018-09-14  12월
# 3                                      비거주 부동산 임대 서비스업  2018-08-08  03월
# ...

# %%
kospi['홈페이지'].isnull().sum()
# Out:
# 32

# %% [markdown]
# ## 비어있는 홈페이지 주소를내 개인프로젝트 배포 주소로 채워라

# %%
kospi_new = kospi.select_dtypes(['object']).fillna('http://ec2-13-209-127-40.ap-northeast-2.compute.amazonaws.com:8080/')

# %%
kospi_new
# Out:
#           회사명                        업종  \
# 0        세아제강                 1차 철강 제조업
# 1        하나제약                   의약품 제조업
# 2     우진아이엔에스               건물설비 설치 공사업
# 3      신한알파리츠              부동산 임대 및 공급업
# 4       한일시멘트  시멘트, 석회, 플라스터 및 그 제품 제조업
# ..        ...                       ...
# 784    CJ대한통운                 도로 화물 운송업
# 785     메리츠화재                       보험업
# 786        경방              방적 및 가공사 제조업
# 787     유수홀딩스       회사 본부 및 경영 컨설팅 서비스업
# 788  한진중공업홀딩스                    기타 금융업
#
#                                                   주요제품         상장일  결산월  \
# 0                                                   강관  2018-10-05  12월
# 1                                                완제의약품  2018-10-02  12월
# 2                                       반도체/디스플레이 코팅덕트  2018-09-14  12월
# 3                                      비거주 부동산 임대 서비스업  2018-08-08  03월
# 4                                        시멘트, 레미콘, 레미탈  2018-08-06  12월
# ...

# %%
kospi_new['홈페이지'].isnull().sum()
# Out:
# 0
